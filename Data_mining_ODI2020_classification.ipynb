# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# %%
df = pd.read_csv('ODI-2020.csv', sep=';')
df
# Out:
#        What programme are you in?  \
# 0           Computational Science
# 1    Quantitative Risk Management
# 2       MSc Computational Science
# 3              MSc Finance - QRM
# 4                              BA
# ..                            ...
# 275       Mechenaical Engineering
# 276                            CS
# 277       Artificial Intelligence
# 278       Artificial Intelligence
# 279       Artificial Intelligence
#
#     Have you taken a course on machine learning?  \
# 0                                             no
# 1                                             no
# 2                                             no
# 3                                             no
# 4                                            yes
# ..                                           ...
# 275                                          yes
# 276                                           no
# 277                                          yes
# 278                                           no
# 279                                          yes
#
#     Have you taken a course on information retrieval?  \
# 0                                             unknown
# 1                                                   0
# 2                                                   0
# 3                                                   0
# 4                                                   0
# ..                                                ...
# 275                                                 1
# 276                                                 0
# 277                                                 1
# 278                                                 0
# 279                                                 1
#
#     Have you taken a course on statistics?  \
# 0                                       mu
# 1                                       mu
# 2                                       mu
# 3                                       mu
# 4                                       mu
# ..                                     ...
# 275                                     mu
# 276                                     mu
# 277                                     mu
# 278                                     mu
# 279                                  sigma
#
#     Have you taken a course on databases? What is your gender?  \
# 0                                      ja               female
# 1                                     nee                 male
# 2                                      ja               female
# 3                                     nee               female
# 4                                      ja                 male
# ..                                    ...                  ...
# 275                                   nee                 male
# 276                                    ja                 male
# 277                                    ja                 male
# 278                                   nee               female
# 279                                   nee                 male
#
#     Chocolate makes you..... When is your birthday (date)?  \
# 0                        fat                    05-08-1998
# 1                    unknown                          1996
# 2                    neither                     12th June
# 3                    neither                    19-06-1994
# 4                    neither                    29-09-1993
# ..                       ...                           ...
# 275                      fat                    17-09-1993
# 276                      fat                         28/10
# 277                  neither                    26-07-1994
# 278                  neither                      3/4/1998
# 279                      fat                    10-11-1995
#
#     Number of neighbors sitting around you? Did you stand up?  \
# 0                                         0                no
# 1                                         2                no
# 2                                         4                no
# 3                                         0                no
# 4                                         0                no
# ..                                      ...               ...
# 275                                       2                no
# 276                                       0                no
# 277                                      12               yes
# 278                                       1                no
# 279                                       0                no
#
#     What is your stress level (0-100)?  \
# 0                                    0
# 1                                   85
# 2                                   50
# 3                                   10
# 4                                   60
# ..                                 ...
# 275                                 69
# 276                                 10
# 277                                 60
# 278                                 70
# 279                                 30
#
#     You can get 100 euros if you win a local DM competition, or we don’t hold any competitions and I give everyone some money (not the same amount!). How much do you think you would deserve then?   \
# 0                                                    4
# 1                                                   25
# 2                                                   10
# 3                                                   99
# 4                                                   80
# ..                                                 ...
# 275                                                  5
# 276                                                100
# 277                                                 75
# 278                                                  2
# 279                                                 10
#
#     Give a random number Time you went to be Yesterday  \
# 0                    227                         22:30
# 1                     65                         23:05
# 2                      3                          10pm
# 3                      2                            23
# 4                      7                         22:00
# ..                   ...                           ...
# 275                    6                          1:00
# 276                    7                         21:45
# 277                   42                         13:37
# 278                   69                         00:00
# 279                   -1                             8
#
#                     What makes a good day for you (1)?  \
# 0                                         Good weather
# 1                                                chill
# 2    Waking up early and preparing for the day by p...
# 3                                     eating good food
# 4                                       Sun is shining
# ..                                                 ...
# 275                                          no corona
# 276                                            Netflix
# 277                                Finishing all tasks
# 278                                               Food
# 279                                          Chocolate
#
#            What makes a good day for you (2)?
# 0                                    Sporting
# 1                                      coffee
# 2       Using the early morning time to study
# 3                  spending time with friends
# 4    Intimate contact with friends and family
# ..                                        ...
# 275                               no corona 2
# 276                                     Chill
# 277     Finding an extra package of ice cream
# 278                                    Orgasm
# 279                                Being slim
#
# [280 rows x 16 columns]

# %%
x = df[df.columns]
#y = df['fruit_label']
x
# Out:
#        What programme are you in?  \
# 0           Computational Science
# 1    Quantitative Risk Management
# 2       MSc Computational Science
# 3              MSc Finance - QRM
# 4                              BA
# ..                            ...
# 275       Mechenaical Engineering
# 276                            CS
# 277       Artificial Intelligence
# 278       Artificial Intelligence
# 279       Artificial Intelligence
#
#     Have you taken a course on machine learning?  \
# 0                                             no
# 1                                             no
# 2                                             no
# 3                                             no
# 4                                            yes
# ..                                           ...
# 275                                          yes
# 276                                           no
# 277                                          yes
# 278                                           no
# 279                                          yes
#
#     Have you taken a course on information retrieval?  \
# 0                                             unknown
# 1                                                   0
# 2                                                   0
# 3                                                   0
# 4                                                   0
# ..                                                ...
# 275                                                 1
# 276                                                 0
# 277                                                 1
# 278                                                 0
# 279                                                 1
#
#     Have you taken a course on statistics?  \
# 0                                       mu
# 1                                       mu
# 2                                       mu
# 3                                       mu
# 4                                       mu
# ..                                     ...
# 275                                     mu
# 276                                     mu
# 277                                     mu
# 278                                     mu
# 279                                  sigma
#
#     Have you taken a course on databases? What is your gender?  \
# 0                                      ja               female
# 1                                     nee                 male
# 2                                      ja               female
# 3                                     nee               female
# 4                                      ja                 male
# ..                                    ...                  ...
# 275                                   nee                 male
# 276                                    ja                 male
# 277                                    ja                 male
# 278                                   nee               female
# 279                                   nee                 male
#
#     Chocolate makes you..... When is your birthday (date)?  \
# 0                        fat                    05-08-1998
# 1                    unknown                          1996
# 2                    neither                     12th June
# 3                    neither                    19-06-1994
# 4                    neither                    29-09-1993
# ..                       ...                           ...
# 275                      fat                    17-09-1993
# 276                      fat                         28/10
# 277                  neither                    26-07-1994
# 278                  neither                      3/4/1998
# 279                      fat                    10-11-1995
#
#     Number of neighbors sitting around you? Did you stand up?  \
# 0                                         0                no
# 1                                         2                no
# 2                                         4                no
# 3                                         0                no
# 4                                         0                no
# ..                                      ...               ...
# 275                                       2                no
# 276                                       0                no
# 277                                      12               yes
# 278                                       1                no
# 279                                       0                no
#
#     What is your stress level (0-100)?  \
# 0                                    0
# 1                                   85
# 2                                   50
# 3                                   10
# 4                                   60
# ..                                 ...
# 275                                 69
# 276                                 10
# 277                                 60
# 278                                 70
# 279                                 30
#
#     You can get 100 euros if you win a local DM competition, or we don’t hold any competitions and I give everyone some money (not the same amount!). How much do you think you would deserve then?   \
# 0                                                    4
# 1                                                   25
# 2                                                   10
# 3                                                   99
# 4                                                   80
# ..                                                 ...
# 275                                                  5
# 276                                                100
# 277                                                 75
# 278                                                  2
# 279                                                 10
#
#     Give a random number Time you went to be Yesterday  \
# 0                    227                         22:30
# 1                     65                         23:05
# 2                      3                          10pm
# 3                      2                            23
# 4                      7                         22:00
# ..                   ...                           ...
# 275                    6                          1:00
# 276                    7                         21:45
# 277                   42                         13:37
# 278                   69                         00:00
# 279                   -1                             8
#
#                     What makes a good day for you (1)?  \
# 0                                         Good weather
# 1                                                chill
# 2    Waking up early and preparing for the day by p...
# 3                                     eating good food
# 4                                       Sun is shining
# ..                                                 ...
# 275                                          no corona
# 276                                            Netflix
# 277                                Finishing all tasks
# 278                                               Food
# 279                                          Chocolate
#
#            What makes a good day for you (2)?
# 0                                    Sporting
# 1                                      coffee
# 2       Using the early morning time to study
# 3                  spending time with friends
# 4    Intimate contact with friends and family
# ..                                        ...
# 275                               no corona 2
# 276                                     Chill
# 277     Finding an extra package of ice cream
# 278                                    Orgasm
# 279                                Being slim
#
# [280 rows x 16 columns]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, random_state=0)
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)
