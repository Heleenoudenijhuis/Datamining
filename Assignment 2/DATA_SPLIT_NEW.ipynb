# %%
import datetime
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import random
# %matplotlib inline
from pylab import rcParams
rcParams['figure.figsize'] = 15, 15

# %%
df = (pd.read_csv('training_set_VU_DM.csv'))
print('loading the dataset, make sure it is in the same folder')
# Out:
# loading the dataset, make sure it is in the same folder

# %%
#datetime features
df['date_time'] =  pd.to_datetime(df['date_time'])
df['day']=df['date_time'].dt.day
df['month']= df['date_time'].dt.month
df['year']=df['date_time'].dt.year

#Find booking date
df['date_time_book'] = df['date_time'] -  pd.to_timedelta(df['srch_booking_window'], unit='d')
df.head()
# Out:
#    srch_id           date_time  site_id  visitor_location_country_id  \
# 0        1 2013-04-04 08:32:15       12                          187
# 1        1 2013-04-04 08:32:15       12                          187
# 2        1 2013-04-04 08:32:15       12                          187
# 3        1 2013-04-04 08:32:15       12                          187
# 4        1 2013-04-04 08:32:15       12                          187
#
#    visitor_hist_starrating  visitor_hist_adr_usd  prop_country_id  prop_id  \
# 0                      NaN                   NaN              219      893
# 1                      NaN                   NaN              219    10404
# 2                      NaN                   NaN              219    21315
# 3                      NaN                   NaN              219    27348
# 4                      NaN                   NaN              219    29604
#
#    prop_starrating  prop_review_score  ...  comp8_rate  comp8_inv  \
# ...

# %%
click_data = df.loc[df['click_bool'] == 1]
click_data.shape
df = df.loc[df['click_bool'] == 0]
# Out:
# (4736468, 54)

# %%
unique = df.srch_id.unique()

#random filter of 10,000 users
idf = random.sample(list(unique), 10000)
dff = df[df.srch_id.isin(idf)]

dff = click_data.append(dff)
# Out:
# (237319, 54)
# (221879, 54)
# (459198, 54)

# %%
dff.to_csv('filtered_training_set.csv')

# %%
df = (pd.read_csv('filtered_training_set.csv'))
df = df.drop(df.columns[0], axis=1)
df
# Out:
#         srch_id            date_time  site_id  visitor_location_country_id  \
# 0             1  2013-04-04 08:32:15       12                          187
# 1             4  2012-12-31 08:59:22        5                          219
# 2             6  2013-06-05 12:27:51       14                          100
# 3             8  2013-03-20 17:50:44        5                          219
# 4            11  2013-02-25 08:39:33        5                          219
# ...         ...                  ...      ...                          ...
# 459193   332755  2013-06-12 07:31:28        5                          219
# 459194   332755  2013-06-12 07:31:28        5                          219
# 459195   332755  2013-06-12 07:31:28        5                          219
# 459196   332755  2013-06-12 07:31:28        5                          219
# 459197   332755  2013-06-12 07:31:28        5                          219
#
# ...

# %%
#divide into 80/20 train/test set

train = df.iloc[0:(len(df)//10*8),]
test = df.iloc[(len(df)//10*8):len(df),]

#remove 4 columns (position, click_bool, booking_bool and gross_bookings_usd) 
#as they are also not in test_set_VU_DM.csv
#test2 = test.drop(columns=['position', 'click_bool', 'booking_bool', 'gross_bookings_usd'])

#export to csv files
train.to_csv('train.csv', index=False)
test.to_csv('test.csv', index=False)
#test2.to_csv('test2.csv', index=False)
